# %% [markdown]
# # Isha Borgaonkar

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('iris2.csv')
data
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.describe(include = 'object')
# Out:
#               class
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
data.isnull().sum()
# Out:
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# class           0
# dtype: int64

# %%
print("\n\nThe features in the dataset are as follows : ")
print("1. Sepal length : ", data['sepal length'].dtype)
print("2. Sepal width : ", data['sepal width'].dtype)
print("3. Petal length : ", data['petal length'].dtype)
print("4. Petal width : ", data['petal width'].dtype)
print("5. Species : ", data['class'].dtype)
# Out:
# The features in the dataset are as follows :
# 1. Sepal length :  float64
# 2. Sepal width :  float64
# 3. Petal length :  float64
# 4. Petal width :  float64
# 5. Species :  object

# %%
sns.histplot(x = data['sepal length'], kde=True)
# Out:
# <AxesSubplot:xlabel='sepal length', ylabel='Count'>

# %%
sns.histplot(x = data['sepal width'], kde=True)
# Out:
# <AxesSubplot:xlabel='sepal width', ylabel='Count'>

# %%
sns.histplot(x = data['petal length'], kde=True)
# Out:
# <AxesSubplot:xlabel='petal length', ylabel='Count'>

# %%
sns.histplot(x = data['petal width'], kde=True)
# Out:
# <AxesSubplot:xlabel='petal width', ylabel='Count'>

# %%
sns.boxplot(data['sepal length'])
# Out:
# C:\Users\ISHA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sepal length'>

# %%
sns.boxplot(data['sepal width'])
# Out:
# C:\Users\ISHA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sepal width'>

# %%
sns.boxplot(data['sepal width'])
# Out:
# C:\Users\ISHA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sepal width'>

# %%
sns.boxplot(data['petal width'])
# Out:
# C:\Users\ISHA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal width'>

# %%
sns.boxplot(x='sepal length',y='class',data=data)
# Out:
# <AxesSubplot:xlabel='sepal length', ylabel='class'>

# %%
sns.boxplot(x='petal length',y='class',data=data)
# Out:
# <AxesSubplot:xlabel='petal length', ylabel='class'>

# %% [markdown]
# Create a histogram for each feature in the dataset.

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 6), constrained_layout = True)

for i in range(4):
    x, y = i // 2, i % 2
    _ = axes[x, y].hist(data[data.columns[i + 1]])
    _ = axes[x, y].set_title(f"Distribution of {data.columns[i + 1][:-2]}")

# %% [markdown]
# Create a boxplot for each feature in the dataset.

# %%
data_to_plot = data[data.columns[1:-1]]

fig, axes = plt.subplots(1, figsize=(12,8))
bp = axes.boxplot(data_to_plot)

# %% [markdown]
# If we observe closely for the box 2, interquartile distance is roughly around 0.75 hence the values lying beyond this range of (third quartile + interquartile distance) i.e. roughly around 4.05 will be considered as outliers. Similarly outliers with other boxplots can be found.
